# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('movies_metadata.csv')
# Out:
# C:\Users\Hp\AppData\Local\Temp\ipykernel_13152\2089594497.py:1: DtypeWarning: Columns (10) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('movies_metadata.csv')

# %%
df.head()
# Out:
#    adult                              belongs_to_collection    budget  \
# 0  False  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1  False                                                NaN  65000000
# 2  False  {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 3  False                                                NaN  16000000
# 4  False  {'id': 96871, 'name': 'Father of the Bride Col...         0
#
#                                               genres  \
# 0  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 1  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# 2  [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...
# 3  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 4                     [{'id': 35, 'name': 'Comedy'}]
#
#                                homepage     id    imdb_id original_language  \
# 0  http://toystory.disney.com/toy-story    862  tt0114709                en
# ...

# %%
df.columns
# Out:
# Index(['adult', 'belongs_to_collection', 'budget', 'genres', 'homepage', 'id',
#        'imdb_id', 'original_language', 'original_title', 'overview',
#        'popularity', 'poster_path', 'production_companies',
#        'production_countries', 'release_date', 'revenue', 'runtime',
#        'spoken_languages', 'status', 'tagline', 'title', 'video',
#        'vote_average', 'vote_count'],
#       dtype='object')

# %%
df.duplicated().isnull()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 45461    False
# 45462    False
# 45463    False
# 45464    False
# 45465    False
# Length: 45466, dtype: bool

# %%
df.isnull().sum()
# Out:
# adult                        0
# belongs_to_collection    40972
# budget                       0
# genres                       0
# homepage                 37684
# id                           0
# imdb_id                     17
# original_language           11
# original_title               0
# overview                   954
# popularity                   5
# poster_path                386
# production_companies         3
# production_countries         3
# release_date                87
# revenue                      6
# runtime                    263
# spoken_languages             6
# status                      87
# tagline                  25054
# title                        6
# video                        6
# vote_average                 6
# vote_count                   6
# dtype: int64

# %%
df.isna().sum()
# Out:
# adult                        0
# belongs_to_collection    40972
# budget                       0
# genres                       0
# homepage                 37684
# id                           0
# imdb_id                     17
# original_language           11
# original_title               0
# overview                   954
# popularity                   5
# poster_path                386
# production_companies         3
# production_countries         3
# release_date                87
# revenue                      6
# runtime                    263
# spoken_languages             6
# status                      87
# tagline                  25054
# title                        6
# video                        6
# vote_average                 6
# vote_count                   6
# dtype: int64

# %%
df.dropna()
# Out:
#        adult                              belongs_to_collection     budget  \
# 9      False  {'id': 645, 'name': 'James Bond Collection', '...   58000000
# 68     False  {'id': 43563, 'name': 'Friday Collection', 'po...    3500000
# 69     False  {'id': 10924, 'name': 'From Dusk Till Dawn Col...   19000000
# 153    False  {'id': 439053, 'name': 'Brooklyn Cigar Store C...    2000000
# 178    False  {'id': 286162, 'name': 'Power Rangers Collecti...   15000000
# ...      ...                                                ...        ...
# 44274  False  {'id': 173710, 'name': 'Planet of the Apes (Re...  152000000
# 44674  False  {'id': 476961, 'name': 'Goon Collection', 'pos...          0
# 44821  False  {'id': 34055, 'name': 'Pokémon Collection', 'p...   16000000
# 44842  False  {'id': 8650, 'name': 'Transformers Collection'...  260000000
# 45029  False  {'id': 417491, 'name': 'Bon Cop Bad Cop Collec...          0
#
#                                                   genres  \
# ...

# %%
df
# Out:
#        adult                              belongs_to_collection    budget  \
# 0      False  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1      False                                                NaN  65000000
# 2      False  {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 3      False                                                NaN  16000000
# 4      False  {'id': 96871, 'name': 'Father of the Bride Col...         0
# ...      ...                                                ...       ...
# 45461  False                                                NaN         0
# 45462  False                                                NaN         0
# 45463  False                                                NaN         0
# 45464  False                                                NaN         0
# 45465  False                                                NaN         0
#
#                                                   genres  \
# ...

# %%
df = df.drop(columns = 'homepage')

# %%
df
# Out:
#        adult                              belongs_to_collection    budget  \
# 0      False  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1      False                                                NaN  65000000
# 2      False  {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 3      False                                                NaN  16000000
# 4      False  {'id': 96871, 'name': 'Father of the Bride Col...         0
# ...      ...                                                ...       ...
# 45461  False                                                NaN         0
# 45462  False                                                NaN         0
# 45463  False                                                NaN         0
# 45464  False                                                NaN         0
# 45465  False                                                NaN         0
#
#                                                   genres      id    imdb_id  \
# ...

# %%
df = df.drop(columns = ['belongs_to_collection','overview','poster_path'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[36], line 1
# ----> 1 df = df.drop(columns = ['belongs_to_collection','overview','poster_path'])
#
# File ~\AppData\Roaming\Python\Python313\site-packages\pandas\core\frame.py:5603, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5455 def drop(
#    5456     self,
#    5457     labels: IndexLabel | None = None,
#    (...)   5464     errors: IgnoreRaise = "raise",
#    5465 ) -> DataFrame | None:
#    5466     """
#    5467     Drop specified labels from rows or columns.
#    5468
#    (...)   5601             weight  1.0     0.8
#    5602     """
# -> 5603     return super().drop(
#    5604         labels=labels,
#    5605         axis=axis,
#    5606         index=index,
#    5607         columns=columns,
#    5608         level=level,
#    5609         inplace=inplace,
# ...

# %%
df
# Out:
#        adult    budget                                             genres  \
# 0      False  30000000  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 1      False  65000000  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# 2      False         0  [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...
# 3      False  16000000  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 4      False         0                     [{'id': 35, 'name': 'Comedy'}]
# ...      ...       ...                                                ...
# 45461  False         0  [{'id': 18, 'name': 'Drama'}, {'id': 10751, 'n...
# 45462  False         0                      [{'id': 18, 'name': 'Drama'}]
# 45463  False         0  [{'id': 28, 'name': 'Action'}, {'id': 18, 'nam...
# 45464  False         0                                                 []
# 45465  False         0                                                 []
#
#            id    imdb_id original_language               original_title  \
# ...

# %%
df
# Out:
#        adult    budget                                             genres  \
# 0      False  30000000  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 1      False  65000000  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# 2      False         0  [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...
# 3      False  16000000  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 4      False         0                     [{'id': 35, 'name': 'Comedy'}]
# ...      ...       ...                                                ...
# 45461  False         0  [{'id': 18, 'name': 'Drama'}, {'id': 10751, 'n...
# 45462  False         0                      [{'id': 18, 'name': 'Drama'}]
# 45463  False         0  [{'id': 28, 'name': 'Action'}, {'id': 18, 'nam...
# 45464  False         0                                                 []
# 45465  False         0                                                 []
#
#            id    imdb_id original_language               original_title  \
# ...

# %%
df = df.drop(columns = 'poster_path')

# %%
df
# Out:
#        adult    budget                                             genres  \
# 0      False  30000000  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 1      False  65000000  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# 2      False         0  [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...
# 3      False  16000000  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 4      False         0                     [{'id': 35, 'name': 'Comedy'}]
# ...      ...       ...                                                ...
# 45461  False         0  [{'id': 18, 'name': 'Drama'}, {'id': 10751, 'n...
# 45462  False         0                      [{'id': 18, 'name': 'Drama'}]
# 45463  False         0  [{'id': 28, 'name': 'Action'}, {'id': 18, 'nam...
# 45464  False         0                                                 []
# 45465  False         0                                                 []
#
#            id    imdb_id original_language               original_title  \
# ...

# %%
df['video'].isna().sum()
# Out:
# np.int64(6)

# %%
df = df.drop(columns = 'video')

# %%
df
# Out:
#        adult    budget                                             genres  \
# 0      False  30000000  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 1      False  65000000  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# 2      False         0  [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...
# 3      False  16000000  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 4      False         0                     [{'id': 35, 'name': 'Comedy'}]
# ...      ...       ...                                                ...
# 45461  False         0  [{'id': 18, 'name': 'Drama'}, {'id': 10751, 'n...
# 45462  False         0                      [{'id': 18, 'name': 'Drama'}]
# 45463  False         0  [{'id': 28, 'name': 'Action'}, {'id': 18, 'nam...
# 45464  False         0                                                 []
# 45465  False         0                                                 []
#
#            id    imdb_id original_language               original_title  \
# ...

# %%
df['budget'].isnull().sum()
# Out:
# np.int64(0)

# %%
df['release_date'] = pd.to_datetime(df['release_date'], errors='coerce')

# %%
df['budget'] = pd.to_numeric(df['budget'], errors='coerce')
df['revenue'] = pd.to_numeric(df['revenue'], errors='coerce')

# %%
df['runtime'] = df['runtime'].fillna(df['runtime'].median())

# %%
df['status'] = df['status'].fillna('Unknown')

# %%
df['tagline'] = df['tagline'].fillna('')

# %%
df['profit'] = df['revenue'] - df['budget']

# %%
df = df[~df['title'].isna()]

# %%
df
# Out:
#        adult      budget                                             genres  \
# 0      False  30000000.0  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 1      False  65000000.0  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# 2      False         0.0  [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...
# 3      False  16000000.0  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 4      False         0.0                     [{'id': 35, 'name': 'Comedy'}]
# ...      ...         ...                                                ...
# 45461  False         0.0  [{'id': 18, 'name': 'Drama'}, {'id': 10751, 'n...
# 45462  False         0.0                      [{'id': 18, 'name': 'Drama'}]
# 45463  False         0.0  [{'id': 28, 'name': 'Action'}, {'id': 18, 'nam...
# 45464  False         0.0                                                 []
# 45465  False         0.0                                                 []
#
# ...

# %%
import ast

df.loc[:, 'genres'] = df['genres'].apply(
    lambda x: ', '.join(d['name'] for d in ast.literal_eval(x)) if pd.notna(x) else None
)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[60], line 3
#       1 import ast
# ----> 3 df.loc[:, 'genres'] = df['genres'].apply(
#       4     lambda x: ', '.join(d['name'] for d in ast.literal_eval(x)) if pd.notna(x) else None
#       5 )
#
# File ~\AppData\Roaming\Python\Python313\site-packages\pandas\core\series.py:4943, in Series.apply(self, func, convert_dtype, args, by_row, **kwargs)
#    4808 def apply(
#    4809     self,
#    4810     func: AggFuncType,
#    (...)   4815     **kwargs,
#    4816 ) -> DataFrame | Series:
#    4817     """
#    4818     Invoke function on values of Series.
#    4819
#    (...)   4934     dtype: float64
#    4935     """
#    4936     return SeriesApply(
#    4937         self,
#    4938         func,
#    4939         convert_dtype=convert_dtype,
#    4940         by_row=by_row,
#    4941         args=args,
# ...

# %%
df
# Out:
#        adult      budget                      genres      id    imdb_id  \
# 0      False  30000000.0   Animation, Comedy, Family     862  tt0114709
# 1      False  65000000.0  Adventure, Fantasy, Family    8844  tt0113497
# 2      False         0.0             Romance, Comedy   15602  tt0113228
# 3      False  16000000.0      Comedy, Drama, Romance   31357  tt0114885
# 4      False         0.0                      Comedy   11862  tt0113041
# ...      ...         ...                         ...     ...        ...
# 45461  False         0.0               Drama, Family  439050  tt6209470
# 45462  False         0.0                       Drama  111109  tt2028550
# 45463  False         0.0     Action, Drama, Thriller   67758  tt0303758
# 45464  False         0.0                              227506  tt0008536
# 45465  False         0.0                              461257  tt6980792
#
#       original_language               original_title popularity  \
# ...

# %%
df.sort_values('revenue', ascending=False).head(10)
# Out:
#        adult       budget                                        genres  \
# 14551  False  237000000.0   Action, Adventure, Fantasy, Science Fiction
# 26555  False  245000000.0   Action, Adventure, Science Fiction, Fantasy
# 1639   False  200000000.0                      Drama, Romance, Thriller
# 17818  False  220000000.0            Science Fiction, Action, Adventure
# 25084  False  150000000.0  Action, Adventure, Science Fiction, Thriller
# 28830  False  190000000.0                                        Action
# 26558  False  280000000.0            Action, Adventure, Science Fiction
# 17437  False  125000000.0                    Family, Fantasy, Adventure
# 22110  False  150000000.0                  Animation, Adventure, Family
# 42222  False  160000000.0                      Family, Fantasy, Romance
#
#            id    imdb_id original_language  \
# 14551   19995  tt0499549                en
# 26555  140607  tt2488496                en
# ...

# %%
df.loc['adult'] = df['adult'].apply(lambda x: x.replace('False','No'))
# Out:
# C:\Users\Hp\AppData\Local\Temp\ipykernel_13152\271039716.py:1: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df.loc['adult'] = df['adult'].apply(lambda x: x.replace('False','No'))
# C:\Users\Hp\AppData\Local\Temp\ipykernel_13152\271039716.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc['adult'] = df['adult'].apply(lambda x: x.replace('False','No'))

# %%
df
# Out:
#       adult      budget                      genres      id    imdb_id  \
# 0        No  30000000.0   Animation, Comedy, Family     862  tt0114709
# 1        No  65000000.0  Adventure, Fantasy, Family    8844  tt0113497
# 2        No         0.0             Romance, Comedy   15602  tt0113228
# 3        No  16000000.0      Comedy, Drama, Romance   31357  tt0114885
# 4        No         0.0                      Comedy   11862  tt0113041
# ...     ...         ...                         ...     ...        ...
# 45462    No         0.0                       Drama  111109  tt2028550
# 45463    No         0.0     Action, Drama, Thriller   67758  tt0303758
# 45464    No         0.0                              227506  tt0008536
# 45465    No         0.0                              461257  tt6980792
# adult   NaN         NaN                         NaN     NaN        NaN
#
#       original_language               original_title popularity  \
# ...

# %%
df['adult'].isna()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 45462    False
# 45463    False
# 45464    False
# 45465    False
# adult     True
# Name: adult, Length: 45461, dtype: bool

# %%
df.loc[:, 'adult'] = df['adult'].replace({'False': 'No', 'True': 'Yes'})

# %%
df
# Out:
#       adult      budget                      genres      id    imdb_id  \
# 0        No  30000000.0   Animation, Comedy, Family     862  tt0114709
# 1        No  65000000.0  Adventure, Fantasy, Family    8844  tt0113497
# 2        No         0.0             Romance, Comedy   15602  tt0113228
# 3        No  16000000.0      Comedy, Drama, Romance   31357  tt0114885
# 4        No         0.0                      Comedy   11862  tt0113041
# ...     ...         ...                         ...     ...        ...
# 45462    No         0.0                       Drama  111109  tt2028550
# 45463    No         0.0     Action, Drama, Thriller   67758  tt0303758
# 45464    No         0.0                              227506  tt0008536
# 45465    No         0.0                              461257  tt6980792
# adult   NaN         NaN                         NaN     NaN        NaN
#
#       original_language               original_title popularity  \
# ...

# %%
df = df.dropna()

# %%
df
# Out:
#       adult      budget                      genres      id    imdb_id  \
# 0        No  30000000.0   Animation, Comedy, Family     862  tt0114709
# 1        No  65000000.0  Adventure, Fantasy, Family    8844  tt0113497
# 2        No         0.0             Romance, Comedy   15602  tt0113228
# 3        No  16000000.0      Comedy, Drama, Romance   31357  tt0114885
# 4        No         0.0                      Comedy   11862  tt0113041
# ...     ...         ...                         ...     ...        ...
# 45460    No         0.0      Drama, Action, Romance   30840  tt0102797
# 45462    No         0.0                       Drama  111109  tt2028550
# 45463    No         0.0     Action, Drama, Thriller   67758  tt0303758
# 45464    No         0.0                              227506  tt0008536
# 45465    No         0.0                              461257  tt6980792
#
#       original_language               original_title popularity  \
# ...

# %%
df[df['vote_count'] > 1000].sort_values('vote_average', ascending=False).head(10)
# Out:
#       adult       budget                                 genres      id  \
# 834      No    6000000.0                           Drama, Crime     238
# 314      No   25000000.0                           Drama, Crime     278
# 40251    No          0.0              Romance, Animation, Drama  372058
# 1176     No     806948.0                Drama, Horror, Thriller     539
# 12481    No  185000000.0         Drama, Action, Crime, Thriller     155
# 522      No   22000000.0                    Drama, History, War     424
# 1178     No   13000000.0                           Drama, Crime     240
# 1184     No   30000000.0                           Drama, Crime     311
# 2843     No   63000000.0                                  Drama     550
# 5481     No   15000000.0  Fantasy, Adventure, Animation, Family     129
#
#          imdb_id original_language               original_title  popularity  \
# 834    tt0068646                en                The Godfather   41.109264
# ...

# %%
df['year'] = df['release_date'].dt.year
# Out:
# C:\Users\Hp\AppData\Local\Temp\ipykernel_13152\1892065409.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['year'] = df['release_date'].dt.year

# %%
df['release_date'].dt.year
# Out:
# 0        1995
# 1        1995
# 2        1995
# 3        1995
# 4        1995
#          ...
# 45460    1991
# 45462    2011
# 45463    2003
# 45464    1917
# 45465    2017
# Name: release_date, Length: 45351, dtype: int32

# %%
df
# Out:
#       adult      budget                      genres      id    imdb_id  \
# 0        No  30000000.0   Animation, Comedy, Family     862  tt0114709
# 1        No  65000000.0  Adventure, Fantasy, Family    8844  tt0113497
# 2        No         0.0             Romance, Comedy   15602  tt0113228
# 3        No  16000000.0      Comedy, Drama, Romance   31357  tt0114885
# 4        No         0.0                      Comedy   11862  tt0113041
# ...     ...         ...                         ...     ...        ...
# 45460    No         0.0      Drama, Action, Romance   30840  tt0102797
# 45462    No         0.0                       Drama  111109  tt2028550
# 45463    No         0.0     Action, Drama, Thriller   67758  tt0303758
# 45464    No         0.0                              227506  tt0008536
# 45465    No         0.0                              461257  tt6980792
#
#       original_language               original_title popularity  \
# ...

# %%
import ast

df.loc[:, 'spoken_languages'] = df['spoken_languages'].apply(
    lambda x: (
        ', '.join(d['name'] for d in ast.literal_eval(x))
        if isinstance(x, str) and x.startswith('[')
        else x
    )
)

# %%
df
# Out:
#       adult      budget                      genres      id    imdb_id  \
# 0        No  30000000.0   Animation, Comedy, Family     862  tt0114709
# 1        No  65000000.0  Adventure, Fantasy, Family    8844  tt0113497
# 2        No         0.0             Romance, Comedy   15602  tt0113228
# 3        No  16000000.0      Comedy, Drama, Romance   31357  tt0114885
# 4        No         0.0                      Comedy   11862  tt0113041
# ...     ...         ...                         ...     ...        ...
# 45460    No         0.0      Drama, Action, Romance   30840  tt0102797
# 45462    No         0.0                       Drama  111109  tt2028550
# 45463    No         0.0     Action, Drama, Thriller   67758  tt0303758
# 45464    No         0.0                              227506  tt0008536
# 45465    No         0.0                              461257  tt6980792
#
#       original_language               original_title popularity  \
# ...

# %%
df.loc[:, 'production_companies'] = df['production_companies'].apply(lambda x: (', '.join(d['name'] for d in ast.literal_eval(x))
        if isinstance(x, str) and x.startswith('[')
        else x
    )
)

# %%
df
# Out:
#       adult      budget                      genres      id    imdb_id  \
# 0        No  30000000.0   Animation, Comedy, Family     862  tt0114709
# 1        No  65000000.0  Adventure, Fantasy, Family    8844  tt0113497
# 2        No         0.0             Romance, Comedy   15602  tt0113228
# 3        No  16000000.0      Comedy, Drama, Romance   31357  tt0114885
# 4        No         0.0                      Comedy   11862  tt0113041
# ...     ...         ...                         ...     ...        ...
# 45460    No         0.0      Drama, Action, Romance   30840  tt0102797
# 45462    No         0.0                       Drama  111109  tt2028550
# 45463    No         0.0     Action, Drama, Thriller   67758  tt0303758
# 45464    No         0.0                              227506  tt0008536
# 45465    No         0.0                              461257  tt6980792
#
#       original_language               original_title popularity  \
# ...

# %%
df.loc[:, 'production_countries'] = df['production_countries'].apply(lambda x: (', '.join(d['name'] for d in ast.literal_eval(x))
        if isinstance(x, str) and x.startswith('[')
        else x
    )
)

# %%
df
# Out:
#       adult      budget                      genres      id    imdb_id  \
# 0        No  30000000.0   Animation, Comedy, Family     862  tt0114709
# 1        No  65000000.0  Adventure, Fantasy, Family    8844  tt0113497
# 2        No         0.0             Romance, Comedy   15602  tt0113228
# 3        No  16000000.0      Comedy, Drama, Romance   31357  tt0114885
# 4        No         0.0                      Comedy   11862  tt0113041
# ...     ...         ...                         ...     ...        ...
# 45460    No         0.0      Drama, Action, Romance   30840  tt0102797
# 45462    No         0.0                       Drama  111109  tt2028550
# 45463    No         0.0     Action, Drama, Thriller   67758  tt0303758
# 45464    No         0.0                              227506  tt0008536
# 45465    No         0.0                              461257  tt6980792
#
#       original_language               original_title popularity  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 45351 entries, 0 to 45465
# Data columns (total 21 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   adult                 45351 non-null  object
#  1   budget                45351 non-null  float64
#  2   genres                45351 non-null  object
#  3   id                    45351 non-null  object
#  4   imdb_id               45351 non-null  object
#  5   original_language     45351 non-null  object
#  6   original_title        45351 non-null  object
#  7   popularity            45351 non-null  object
#  8   production_companies  45351 non-null  object
#  9   production_countries  45351 non-null  object
#  10  release_date          45351 non-null  datetime64[ns]
#  11  revenue               45351 non-null  float64
#  12  runtime               45351 non-null  float64
#  13  spoken_languages      45351 non-null  object
# ...

# %%
df.isna().sum()
# Out:
# adult                   0
# budget                  0
# genres                  0
# id                      0
# imdb_id                 0
# original_language       0
# original_title          0
# popularity              0
# production_companies    0
# production_countries    0
# release_date            0
# revenue                 0
# runtime                 0
# spoken_languages        0
# status                  0
# tagline                 0
# title                   0
# vote_average            0
# vote_count              0
# profit                  0
# year                    0
# dtype: int64
